# %% [markdown]
# <a href="https://colab.research.google.com/github/manojach87/miscellaneous/blob/master/Celsius_to_Farenheit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
#tf.logging.set_verbosity(tf.logging.ERROR)

# %%
def cel2far(c):
  f=c*1.8+32
  return(f)

# %%
import numpy as np
import pandas as pd

# %%
c=np.array([-40,-10,0,8,15,22,38],dtype=float)
f=cel2far(c)

# %%
l0=tf.keras.layers.Dense(units=1, input_shape=[1])

# %%
model=tf.keras.Sequential([l0])

# %%
model.compile(loss='mean_squared_error',optimizer=tf.keras.optimizers.Adam(0.1))

# %%
history=model.fit(c,f,epochs=500,verbose=True)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 485.3297
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 486.4837
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 477.0410
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 473.7549
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 471.4852
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 466.4177
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 460.4819
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 455.6255
# Epoch 9/500
# 1/1 [==============================] - 0s 819us/step - loss: 452.1404
# Epoch 10/500
# 1/1 [==============================] - 0s 853us/step - loss: 448.8253
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 444.6619
# Epoch 12/500
# ...

# %%
import matplotlib.pyplot as plt
plt.xlabel("Epoch Number")
plt.ylabel("Loss Magnitude")
plt.plot(history.history["loss"])

# %%
model.predict([2])
# Out:
# array([[35.29332]], dtype=float32)

# %%
cel2far(2)
# Out:
# 35.6

# %%
print("Layer Variables: {}".format(l0.get_weights()))
# Out:
# Layer Variables: [array([[1.8026304]], dtype=float32), array([31.688059], dtype=float32)]

# %%
l0=tf.keras.layers.Dense(units=4, input_shape=[1])
l1=tf.keras.layers.Dense(units=4)
l2=tf.keras.layers.Dense(units=1)
model= tf.keras.Sequential([l0,l1,l2])
model.compile(loss='mean_squared_error',optimizer=tf.keras.optimizers.Adam(0.1))
history=model.fit(c,f,epochs=500,verbose=False)
print("trained!!")
print(model.predict([100]))

print("Layer Variables: {}".format(l0.get_weights()))
print("Layer Variables: {}".format(l1.get_weights()))
print("Layer Variables: {}".format(l2.get_weights()))
# Out:
# trained!!
# [[212.00005]]
# Layer Variables: [array([[-0.4636532 ,  0.552467  , -0.06267308, -0.06932367]],
#       dtype=float32), array([-3.6233509 ,  3.555683  ,  3.040679  ,  0.31571737], dtype=float32)]
# Layer Variables: [array([[-1.1768396 , -1.2383844 , -0.56641275,  0.19324154],
#        [ 0.14375357,  0.9697968 ,  0.48866928, -0.9923514 ],
#        [ 1.2171504 ,  0.9623584 ,  0.04584898, -0.0552123 ],
#        [ 0.23189013, -0.23529558,  0.36816752, -0.39425057]],
#       dtype=float32), array([ 3.5578706,  3.6373587,  2.067913 , -1.9730264], dtype=float32)]
# Layer Variables: [array([[ 1.0109987 ],
#        [ 0.90256   ],
#        [ 0.24452808],
#        [-0.29001397]], dtype=float32), array([3.3621309], dtype=float32)]
